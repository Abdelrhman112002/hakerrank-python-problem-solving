# %% [markdown]
# # Task-7 : Print Function

# %% [markdown]
# # Answer :

# %%
if __name__ == '__main__':
    n = int(input())
    if 1 <= n <= 150:
        for i in range(1, n+1):
            print(f"{i}", end="")
# Out:
# 123
