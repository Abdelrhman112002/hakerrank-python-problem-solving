# %% [markdown]
# # Task-017 : Eye and Identity

# %% [markdown]
# # Answer :

# %%
import numpy
numpy.set_printoptions(legacy='1.13')

N, M = map(int, input().split())

print(numpy.eye(N, M, k=0, dtype=float))
# Out:
# [[ 1.  0.  0.]
#  [ 0.  1.  0.]
#  [ 0.  0.  1.]]
